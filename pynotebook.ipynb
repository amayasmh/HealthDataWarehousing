# %%
import pandas as pd
df = pd.read_csv("Data/raw/donnees-urgences-SOS-medecins.csv",
                        sep=";",
                        dtype="unicode")
df
# Out:
#         dep date_de_passage sursaud_cl_age_corona nbre_pass_corona  \
# 0        01      2022-12-26                     0                9
# 1        01      2022-12-26                     1                0
# 2        01      2022-12-26                     2                0
# 3        01      2022-12-26                     3                1
# 4        01      2022-12-26                     4                1
# ...     ...             ...                   ...              ...
# 214216  976      2023-10-24                     2                0
# 214217  976      2023-10-24                     3                0
# 214218  976      2023-10-24                     4                0
# 214219  976      2023-10-24                     5                0
# 214220  976      2023-10-24                     6              NaN
#
#        nbre_pass_tot nbre_hospit_corona nbre_pass_corona_h nbre_pass_corona_f  \
# 0                435                  4                  6                  3
# ...
